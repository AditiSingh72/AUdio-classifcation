# %%
#Audio Classification using Machine learning
#EDA : Exploratory Data Analysis : How does a soound wave look like
#librosa : library for Audio Classification

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Displaying Audio files in the form of signals
filename = 'UrbanSound8K/audio/fold10/100648-1-0-0.wav'

# %%
#Helps to display graphs of the sound waves
import IPython.display as ipd
import librosa
import librosa.display

# %%
#Dog Sound
plt.figure(figsize=(14,5))
data,sample_rate = librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
#Help us to load the audio that is in the form of wave file
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#In audio a sample rate defines how may times per second a sound is sampled
sample_rate
#librosa read any mechanism and converts into a sample rate of 22050
# Out:
# 48000

# %% [markdown]
# * In mono audio, the same audio content is played through all speakers or headphones, and there is no spatial separation of sound.
# * Stereo audio is used to create a sense of spatialization and directionality in sound. When you listen to stereo audio through headphones or a stereo speaker setup, you can perceive the sound coming from different directions, which enhances the immersive quality of the listening experience.

# %%
from scipy.io import wavfile
wave_sample_rate,wave_audio = wavfile.read(filename)

# %%
wave_sample_rate
# Out:
# 48000

# %%
#any audio signals can be represented in this numerical data which can be combined to generate a wave
wave_audio
# Out:
# array([   -5,    -5,    -6, ..., -1576, -1566, -1557], dtype=int16)

# %%
#scipy doesn't normlize hese vlu however librosa does
data
# Out:
# array([9.3132257e-10, 5.1222742e-09, 6.5192580e-09, ..., 1.8561386e-02,
#        2.6891196e-02, 3.4412302e-02], dtype=float32)

# %%
import pandas as pd
metadata=pd.read_csv("UrbanSound8K/metadata/Urb")anSound8K.csv
